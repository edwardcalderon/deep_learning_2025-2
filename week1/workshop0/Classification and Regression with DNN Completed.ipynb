# %% [markdown]
# # Classification and Regression using Deep Learning on tabular data

# %% [markdown]
# This notebook is a coding companion to create your very first neural network to predict whether the house price is below or above median value (CLASSIFICATION). Steps are:
#
# - Exploring and Processing the Data
# - Building and Training our Neural Network
# - Visualizing Loss and Accuracy
# - Adding Regularization to our Neural Network
#
# Results might differ because a degree of randomness in the way we split our dataset as well as the initialization of our neural network.
#
# This notebook is based on Joseph Lee Wei En, 2019 at medium.com

# %% [markdown]
# # Exploring and Processing the Data

# %% [markdown]
# We first have to read in the CSV file that we've been given. We'll use a package called pandas for that:

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ed\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ed\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ed\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ed\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ed\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ed\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data_path = r"./housepricedata.csv"
df = pd.read_csv(data_path, sep = ',', encoding='utf-8') #wherever resides your data, if .ipnb and .csv are in the same folder no need to worry!
df.head(6)
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
# 5    14115            5            5          796         1         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1
# 5             1             5           0         480                 0

# %%
#print(len(df. columns))
#len(df)
df.shape
# Out:
# (1460, 11)

# %% [markdown]
# The dataset is now in a pandas dataframe. To convert it to an array, simply access its values:

# %%
dataset = df.values

# %% [markdown]
# Now, we choose our input features and the Target we wish to predict.

# %%
X = dataset[:,0:10]
Y = dataset[:,10]

# %% [markdown]
# Normalizing our data is very important, as we want the input features to be on the same order of magnitude to make our training easier. We'll use a min-max scaler from Scikit-learn library which scales our data to be between 0 and 1.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ed\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ed\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ed\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ed\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ed\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale  # Objective, target or output variable should not be scaled
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %% [markdown]
# Lastly, we wish to set aside some parts of our dataset for a validation set and a test set. We use the function train_test_split from scikit-learn to do that.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.1)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1314, 10) (73, 10) (73, 10) (1314,) (73,) (73,)

# %% [markdown]
# # Building and Training Our First Neural Network for "Classification"

# %%
pip install -U tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\ed\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ed\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ed\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ed\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ed\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ed\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in c:\users\ed\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ed\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ed\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\ed\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\ed\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\ed\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ed\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ed\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ed\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ed\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We will be using Keras to build our architecture. Let's import the code from Keras that we will need to use:

# %%
pip install protobuf==5.28.*
# Out:
# Requirement already satisfied: protobuf==5.28.* in c:\users\ed\anaconda3\lib\site-packages (5.28.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
# Install NVIDIA Collective Communications Library (NCCL) for CUDA 12
# NCCL enables efficient multi-GPU communication for deep learning frameworks
# !pip install nvidia-pyindex && nvidia-nccl-cu12
# Out:
# Collecting nvidia-pyindex
#   Downloading nvidia-pyindex-1.0.9.tar.gz (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: nvidia-pyindex
#   Building wheel for nvidia-pyindex (pyproject.toml): started
#   Building wheel for nvidia-pyindex (pyproject.toml): finished with status 'error'
# Failed to build nvidia-pyindex
#   error: subprocess-exited-with-error
#
#   Building wheel for nvidia-pyindex (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [129 lines of output]
#   C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved :: Apache Software License
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib\nvidia_pyindex
#   copying nvidia_pyindex\cmdline.py -> build\lib\nvidia_pyindex
#   copying nvidia_pyindex\utils.py -> build\lib\nvidia_pyindex
#   copying nvidia_pyindex\__init__.py -> build\lib\nvidia_pyindex
#   running egg_info
#   writing nvidia_pyindex.egg-info\PKG-INFO
#   writing dependency_links to nvidia_pyindex.egg-info\dependency_links.txt
#   writing entry points to nvidia_pyindex.egg-info\entry_points.txt
#   writing top-level names to nvidia_pyindex.egg-info\top_level.txt
#   reading manifest file 'nvidia_pyindex.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE.md'
#   writing manifest file 'nvidia_pyindex.egg-info\SOURCES.txt'
#   installing to build\bdist.win-amd64\wheel
#   running install
#   %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#   COMMAND: InstallCommand
#   %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#   Traceback (most recent call last):
#     File "C:\Users\ed\AppData\Local\Temp\pip-install-io9wecel\nvidia-pyindex_04b485fb74ec4eb6b07e67ac7330194d\nvidia_pyindex\utils.py", line 20, in get_configuration_files
#       output = subprocess.check_output(command, stderr=subprocess.STDOUT)
#     File "C:\Users\ed\anaconda3\Lib\subprocess.py", line 472, in check_output
#       return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#              ~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                  **kwargs).stdout
#                  ^^^^^^^^^
#     File "C:\Users\ed\anaconda3\Lib\subprocess.py", line 577, in run
#       raise CalledProcessError(retcode, process.args,
#                                output=stdout, stderr=stderr)
#   subprocess.CalledProcessError: Command '['C:\\Users\\ed\\Documents\\maestria\\jupyter\\Scripts\\python.exe', '-c', 'from pip._internal.configuration import get_configuration_files; print(get_configuration_files())']' returned non-zero exit status 1.
#
#   The above exception was the direct cause of the following exception:
#
#   Traceback (most recent call last):
#     File "C:\Users\ed\Documents\maestria\jupyter\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#       ~~~~^^
#     File "C:\Users\ed\Documents\maestria\jupyter\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ed\Documents\maestria\jupyter\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 280, in build_wheel
#       return _build_backend().build_wheel(
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#           wheel_directory, config_settings, metadata_directory
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       )
#       ^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\build_meta.py", line 435, in build_wheel
#       return _build(['bdist_wheel', '--dist-info-dir', str(metadata_directory)])
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\build_meta.py", line 423, in _build
#       return self._build_with_temp_dir(
#              ~~~~~~~~~~~~~~~~~~~~~~~~~^
#           cmd,
#           ^^^^
#       ...<3 lines>...
#           self._arbitrary_args(config_settings),
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       )
#       ^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\build_meta.py", line 404, in _build_with_temp_dir
#       self.run_setup()
#       ~~~~~~~~~~~~~~^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\build_meta.py", line 512, in run_setup
#       super().run_setup(setup_script=setup_script)
#       ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#       exec(code, locals())
#       ~~~~^^^^^^^^^^^^^^^^
#     File "<string>", line 238, in <module>
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\__init__.py", line 115, in setup
#       return distutils.core.setup(**attrs)
#              ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 186, in setup
#       return run_commands(dist)
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 202, in run_commands
#       dist.run_commands()
#       ~~~~~~~~~~~~~~~~~^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 1002, in run_commands
#       self.run_command(cmd)
#       ~~~~~~~~~~~~~~~~^^^^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\dist.py", line 1102, in run_command
#       super().run_command(command)
#       ~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 1021, in run_command
#       cmd_obj.run()
#       ~~~~~~~~~~~^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\command\bdist_wheel.py", line 405, in run
#       self.run_command("install")
#       ~~~~~~~~~~~~~~~~^^^^^^^^^^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 357, in run_command
#       self.distribution.run_command(command)
#       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\dist.py", line 1102, in run_command
#       super().run_command(command)
#       ~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#     File "C:\Users\ed\AppData\Local\Temp\pip-build-env-fhs1ndc9\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 1021, in run_command
#       cmd_obj.run()
#       ~~~~~~~~~~~^^
#     File "<string>", line 172, in run
#     File "<string>", line 71, in _install_nvidia_pypi_index
#     File "C:\Users\ed\AppData\Local\Temp\pip-install-io9wecel\nvidia-pyindex_04b485fb74ec4eb6b07e67ac7330194d\nvidia_pyindex\utils.py", line 24, in get_configuration_files
#       raise RuntimeError(output) from e
#   RuntimeError: Traceback (most recent call last):
#
#     File "<string>", line 1, in <module>
#
#       from pip._internal.configuration import get_configuration_files; print(get_configuration_files())
#
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   ModuleNotFoundError: No module named 'pip'
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for nvidia-pyindex
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (nvidia-pyindex)

# %%
pip install --extra-index-url https://pypi.nvidia.com tensorflow[and-cuda]
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Requirement already satisfied: tensorflow[and-cuda] in c:\users\ed\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ed\anaconda3\lib\site-packages (from tensorflow[and-cuda]) (0.5.3)
# Collecting nvidia-cublas-cu12<13.0,>=12.5.3.2 (from tensorflow[and-cuda])
#   Using cached nvidia_cublas_cu12-12.9.1.4-py3-none-win_amd64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12<13.0,>=12.5.82 (from tensorflow[and-cuda])
#   Using cached nvidia_cuda_cupti_cu12-12.9.79-py3-none-win_amd64.whl.metadata (1.8 kB)
# Collecting nvidia-cuda-nvcc-cu12<13.0,>=12.5.82 (from tensorflow[and-cuda])
#   Using cached nvidia_cuda_nvcc_cu12-12.9.86-py3-none-win_amd64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc-cu12<13.0,>=12.5.82 (from tensorflow[and-cuda])
#   Downloading https://pypi.nvidia.com/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.9.86-py3-none-win_amd64.whl (76.4 MB)
#      ---------------------------------------- 0.0/76.4 MB ? eta -:--:--
#       --------------------------------------- 1.0/76.4 MB 8.0 MB/s eta 0:00:10
#      - -------------------------------------- 3.4/76.4 MB 9.4 MB/s eta 0:00:08
#      --- ------------------------------------ 6.0/76.4 MB 10.3 MB/s eta 0:00:07
#      ---- ----------------------------------- 8.9/76.4 MB 11.2 MB/s eta 0:00:07
#      ------ --------------------------------- 11.5/76.4 MB 11.3 MB/s eta 0:00:06
#      ------- -------------------------------- 13.9/76.4 MB 11.4 MB/s eta 0:00:06
#      -------- ------------------------------- 16.3/76.4 MB 11.3 MB/s eta 0:00:06
#      --------- ------------------------------ 18.6/76.4 MB 11.5 MB/s eta 0:00:06
#      ----------- ---------------------------- 21.2/76.4 MB 11.5 MB/s eta 0:00:05
#      ------------ --------------------------- 23.6/76.4 MB 11.6 MB/s eta 0:00:05
#      ------------- -------------------------- 26.2/76.4 MB 11.5 MB/s eta 0:00:05
#      --------------- ------------------------ 29.1/76.4 MB 11.6 MB/s eta 0:00:05
#      ---------------- ----------------------- 31.5/76.4 MB 11.6 MB/s eta 0:00:04
#      ----------------- ---------------------- 33.8/76.4 MB 11.7 MB/s eta 0:00:04
#      ------------------- -------------------- 36.7/76.4 MB 11.7 MB/s eta 0:00:04
#      -------------------- ------------------- 39.1/76.4 MB 11.6 MB/s eta 0:00:04
#      --------------------- ------------------ 41.9/76.4 MB 11.7 MB/s eta 0:00:03
#      ----------------------- ---------------- 44.0/76.4 MB 11.6 MB/s eta 0:00:03
#      ------------------------ --------------- 46.7/76.4 MB 11.7 MB/s eta 0:00:03
#      ------------------------- -------------- 49.5/76.4 MB 11.7 MB/s eta 0:00:03
#      --------------------------- ------------ 51.6/76.4 MB 11.6 MB/s eta 0:00:03
#      ---------------------------- ----------- 54.5/76.4 MB 11.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 56.6/76.4 MB 11.7 MB/s eta 0:00:02
#      ------------------------------- -------- 59.2/76.4 MB 11.7 MB/s eta 0:00:02
#      -------------------------------- ------- 61.6/76.4 MB 11.7 MB/s eta 0:00:02
#      --------------------------------- ------ 64.2/76.4 MB 11.7 MB/s eta 0:00:02
#      ---------------------------------- ----- 66.3/76.4 MB 11.7 MB/s eta 0:00:01
#      ------------------------------------ --- 69.2/76.4 MB 11.8 MB/s eta 0:00:01
#      ------------------------------------- -- 71.8/76.4 MB 11.8 MB/s eta 0:00:01
#      -------------------------------------- - 73.9/76.4 MB 11.8 MB/s eta 0:00:01
#      ---------------------------------------- 76.4/76.4 MB 11.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12<13.0,>=12.5.82 (from tensorflow[and-cuda])
#   Downloading https://pypi.nvidia.com/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.9.79-py3-none-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#      -------------------------- ------------- 2.4/3.6 MB 11.8 MB/s eta 0:00:01
#      ---------------------------------------- 3.6/3.6 MB 10.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12<10.0,>=9.3.0.75 (from tensorflow[and-cuda])
#   Downloading https://pypi.nvidia.com/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.13.0.50-py3-none-win_amd64.whl (630.6 MB)
#      ---------------------------------------- 0.0/630.6 MB ? eta -:--:--
#      ---------------------------------------- 2.1/630.6 MB 10.0 MB/s eta 0:01:03
#      ---------------------------------------- 4.7/630.6 MB 11.8 MB/s eta 0:00:54
#      ---------------------------------------- 7.3/630.6 MB 11.4 MB/s eta 0:00:55
#       --------------------------------------- 9.7/630.6 MB 11.9 MB/s eta 0:00:53
#       --------------------------------------- 12.3/630.6 MB 11.6 MB/s eta 0:00:54
MB/s eta 0:00:00
# Collecting nvidia-curand-cu12<11.0,>=10.3.6.82 (from tensorflow[and-cuda])
#   Downloading https://pypi.nvidia.com/nvidia-curand-cu12/nvidia_curand_cu12-10.3.10.19-py3-none-win_amd64.whl (68.8 MB)
#      ---------------------------------------- 0.0/68.8 MB ? eta -:--:--
#      - -------------------------------------- 2.4/68.8 MB 11.2 MB/s eta 0:00:06
#      -- ------------------------------------- 5.0/68.8 MB 11.6 MB/s eta 0:00:06
#      ---- ----------------------------------- 7.6/68.8 MB 11.9 MB/s eta 0:00:06
#      ----- ---------------------------------- 9.7/68.8 MB 11.9 MB/s eta 0:00:05
#      ------- -------------------------------- 12.1/68.8 MB 11.5 MB/s eta 0:00:05
#      -------- ------------------------------- 14.7/68.8 MB 11.8 MB/s eta 0:00:05
#      --------- ------------------------------ 17.0/68.8 MB 11.8 MB/s eta 0:00:05
#      ----------- ---------------------------- 19.4/68.8 MB 11.7 MB/s eta 0:00:05
#      ------------ --------------------------- 22.3/68.8 MB 11.8 MB/s eta 0:00:04
#      -------------- ------------------------- 24.9/68.8 MB 11.8 MB/s eta 0:00:04
#      ---------------- ----------------------- 27.5/68.8 MB 11.8 MB/s eta 0:00:04
#      ----------------- ---------------------- 30.1/68.8 MB 11.8 MB/s eta 0:00:04
#      ------------------ --------------------- 32.5/68.8 MB 11.8 MB/s eta 0:00:04
#      -------------------- ------------------- 34.6/68.8 MB 11.7 MB/s eta 0:00:03
#      --------------------- ------------------ 37.2/68.8 MB 11.7 MB/s eta 0:00:03
#      ----------------------- ---------------- 39.8/68.8 MB 11.7 MB/s eta 0:00:03
#      ------------------------ --------------- 42.2/68.8 MB 11.7 MB/s eta 0:00:03
#      ------------------------- -------------- 44.6/68.8 MB 11.8 MB/s eta 0:00:03
#      --------------------------- ------------ 46.9/68.8 MB 11.8 MB/s eta 0:00:02
#      ---------------------------- ----------- 49.8/68.8 MB 11.8 MB/s eta 0:00:02
#      ------------------------------ --------- 52.4/68.8 MB 11.8 MB/s eta 0:00:02
#      ------------------------------- -------- 54.8/68.8 MB 11.8 MB/s eta 0:00:02
#      --------------------------------- ------ 57.1/68.8 MB 11.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 59.8/68.8 MB 11.8 MB/s eta 0:00:01
#      ------------------------------------ --- 62.4/68.8 MB 11.8 MB/s eta 0:00:01
#      ------------------------------------- -- 64.7/68.8 MB 11.8 MB/s eta 0:00:01
#      ---------------------------------------  67.1/68.8 MB 11.8 MB/s eta 0:00:01
#      ---------------------------------------- 68.8/68.8 MB 11.8 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12<12.0,>=11.6.3.83 (from tensorflow[and-cuda])
#   Downloading https://pypi.nvidia.com/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.5.82-py3-none-win_amd64.whl (326.2 MB)
#      ---------------------------------------- 0.0/326.2 MB ? eta -:--:--
#      ---------------------------------------- 2.1/326.2 MB 11.9 MB/s eta 0:00:28
#       --------------------------------------- 5.0/326.2 MB 11.9 MB/s eta 0:00:28
#       --------------------------------------- 7.6/326.2 MB 11.9 MB/s eta 0:00:27
#      - -------------------------------------- 10.0/326.2 MB 11.7 MB/s eta 0:00:28
#      - -------------------------------------- 11.8/326.2 MB 11.8 MB/s eta 0:00:27
#      - -------------------------------------- 13.9/326.2 MB 10.9 MB/s eta 0:00:29
#      -- ------------------------------------- 17.0/326.2 MB 11.4 MB/s eta 0:00:28
#      ------------------------------------ --- 331.1/362.5 MB 11.7 MB/s eta 0:00:03
#      ------------------------------------ --- 333.7/362.5 MB 11.7 MB/s eta 0:00:03
#      ------------------------------------- -- 336.1/362.5 MB 11.7 MB/s eta 0:00:03
#      ------------------------------------- -- 338.4/362.5 MB 11.7 MB/s eta 0:00:03
#      ------------------------------------- -- 341.3/362.5 MB 11.7 MB/s eta 0:00:02
#      ------------------------------------- -- 343.7/362.5 MB 11.7 MB/s eta 0:00:02
#      -------------------------------------- - 346.0/362.5 MB 11.7 MB/s eta 0:00:02
#      -------------------------------------- - 348.4/362.5 MB 11.7 MB/s eta 0:00:02
#      -------------------------------------- - 350.7/362.5 MB 11.7 MB/s eta 0:00:02
#      -------------------------------------- - 353.4/362.5 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------------  356.0/362.5 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------------  358.4/362.5 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------------  361.0/362.5 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------------- 362.5/362.5 MB 11.7 MB/s eta 0:00:00
# INFO: pip is looking at multiple versions of tensorflow[and-cuda] to determine which version is compatible with other requirements. This could take a while.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement nvidia-nccl-cu12<3.0,>=2.25.1; extra == "and-cuda" (from tensorflow[and-cuda]) (from versions: 0.0.1.dev5)
# ERROR: No matching distribution found for nvidia-nccl-cu12<3.0,>=2.25.1; extra == "and-cuda"

# %% [markdown]
# DNN are Sequential, so we need to import Sequential model, which means that we merely need to describe the layers in sequence. Our neural network would have three layers:
#
# - Hidden layer 1: 16 neurons, ReLU activation
# - Hidden layer 2: 16 neurons, ReLU activation
# - Output Layer: 1 neuron, Sigmoid activation

# %%
model = Sequential([
    Dense(16, activation='relu', input_shape=(10,)),
    Dropout(0.3),
    Dense(16, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid'),
])
# Out:
# C:\Users\ed\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Now that we've got our architecture specified, we need to find the best numbers for it. Before we start our training, we have to configure the model by
# - Telling it what algorithm you want to use to do the optimization (we'll use stochastic gradient descent)
# - Telling it what loss function to use (for binary classification, we will use binary cross entropy)
# - Telling what metrics you want to track apart from the loss function (we want to track accuracy)
#
# We do so below:

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Training on the data is pretty straightforward, the function is called 'fit' as we are fitting the parameters to the data. We specify:
# - what data we are training on, which is X_train and Y_train
# - the size of our mini-batch
# - how long we want to train it for (epochs)
# - what our validation data is so that the model will tell us how we are doing on the validation data at each point.
#
# This function will output a history, which we save under the variable hist. We'll use this variable a little later.

# %%
hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val)) #epochs y bs son hyperparameters
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5761 - loss: 0.6756 - val_accuracy: 0.6712 - val_loss: 0.6738
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5898 - loss: 0.6754 - val_accuracy: 0.7808 - val_loss: 0.6676
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6126 - loss: 0.6713 - val_accuracy: 0.7534 - val_loss: 0.6655
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6050 - loss: 0.6695 - val_accuracy: 0.7808 - val_loss: 0.6619
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9178 - loss: 0.2743
# 0.9178082346916199

# %% [markdown]
# # Visualizing Loss and Accuracy

# %% [markdown]
# Import the relevant package we need to do the visualization

# %% [markdown]
# Import the relevant package we need to do the visualization

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ed\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ed\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ed\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ed\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ed\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\ed\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ed\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ed\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ed\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ed\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ed\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# We want to visualize the training loss and the validation loss like this:

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train_loss', 'Valid_loss'], loc='upper right')
plt.show()

# %% [markdown]
# We can also visualize the training accuracy and the validation accuracy like this:

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Valid'], loc='lower right')
plt.show()

# %%
# Define the neural network model
model = Sequential([
    Dense(8, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(8, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Sigmoid for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
hist = model.fit(X_train, Y_train, epochs=40, batch_size=16, validation_data=(X_test, Y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/40
# C:\Users\ed\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4886 - loss: 0.6986 - val_accuracy: 0.5616 - val_loss: 0.6889
# Epoch 2/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5228 - loss: 0.6877 - val_accuracy: 0.8082 - val_loss: 0.6724
# Epoch 3/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5693 - loss: 0.6713 - val_accuracy: 0.8630 - val_loss: 0.6336
# Epoch 4/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5708 - loss: 0.6604 - val_accuracy: 0.8767 - val_loss: 0.6151
# Epoch 5/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5997 - loss: 0.6437 - val_accuracy: 0.8630 - val_loss: 0.5953
# Epoch 6/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6294 - loss: 0.6306 - val_accuracy: 0.8767 - val_loss: 0.5623
# Epoch 7/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6339 - loss: 0.6058 - val_accuracy: 0.8767 - val_loss: 0.5428
# Epoch 8/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6202 - loss: 0.6116 - val_accuracy: 0.8904 - val_loss: 0.5238
# Epoch 9/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6385 - loss: 0.6065 - val_accuracy: 0.8767 - val_loss: 0.5123
# Epoch 10/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6461 - loss: 0.5826 - val_accuracy: 0.8904 - val_loss: 0.4866
# Epoch 11/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6720 - loss: 0.5703 - val_accuracy: 0.8630 - val_loss: 0.4668
# Epoch 12/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6720 - loss: 0.5605 - val_accuracy: 0.8767 - val_loss: 0.4590
# Epoch 13/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6895 - loss: 0.5457 - val_accuracy: 0.8904 - val_loss: 0.4401
# Epoch 14/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7085 - loss: 0.5349 - val_accuracy: 0.8904 - val_loss: 0.4267
# Epoch 15/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7268 - loss: 0.5298 - val_accuracy: 0.8904 - val_loss: 0.4140
# Epoch 16/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7169 - loss: 0.5195 - val_accuracy: 0.8904 - val_loss: 0.4103
# Epoch 17/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7352 - loss: 0.5172 - val_accuracy: 0.9178 - val_loss: 0.4068
# Epoch 18/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6979 - loss: 0.5255 - val_accuracy: 0.8904 - val_loss: 0.4018
# Epoch 19/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7146 - loss: 0.5315 - val_accuracy: 0.9315 - val_loss: 0.4082
# Epoch 20/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7207 - loss: 0.5153 - val_accuracy: 0.8904 - val_loss: 0.3894
# Epoch 21/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7489 - loss: 0.4903 - val_accuracy: 0.9041 - val_loss: 0.3781
# Epoch 22/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7199 - loss: 0.5123 - val_accuracy: 0.9178 - val_loss: 0.3851
# Epoch 23/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7443 - loss: 0.4969 - val_accuracy: 0.8904 - val_loss: 0.3740
# Epoch 24/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7412 - loss: 0.4857 - val_accuracy: 0.9315 - val_loss: 0.3736
# Epoch 25/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7481 - loss: 0.5144 - val_accuracy: 0.8904 - val_loss: 0.3817
# Epoch 26/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7549 - loss: 0.4853 - val_accuracy: 0.9452 - val_loss: 0.3719
# Epoch 27/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7580 - loss: 0.4771 - val_accuracy: 0.9178 - val_loss: 0.3642
# Epoch 28/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7542 - loss: 0.5012 - val_accuracy: 0.9178 - val_loss: 0.3652
# Epoch 29/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7519 - loss: 0.4799 - val_accuracy: 0.9178 - val_loss: 0.3599
# Epoch 30/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7603 - loss: 0.4711 - val_accuracy: 0.9041 - val_loss: 0.3601
# Epoch 31/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7511 - loss: 0.4961 - val_accuracy: 0.9178 - val_loss: 0.3643
# Epoch 32/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7557 - loss: 0.4677 - val_accuracy: 0.9178 - val_loss: 0.3604
# Epoch 33/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7572 - loss: 0.4897 - val_accuracy: 0.9041 - val_loss: 0.3601
# Epoch 34/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7618 - loss: 0.4713 - val_accuracy: 0.9178 - val_loss: 0.3558
# Epoch 35/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7656 - loss: 0.4750 - val_accuracy: 0.9178 - val_loss: 0.3574
# Epoch 36/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7519 - loss: 0.4786 - val_accuracy: 0.9178 - val_loss: 0.3577
# Epoch 37/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7382 - loss: 0.4835 - val_accuracy: 0.9041 - val_loss: 0.3544
# Epoch 38/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7557 - loss: 0.4660 - val_accuracy: 0.9178 - val_loss: 0.3555
# Epoch 39/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7664 - loss: 0.4668 - val_accuracy: 0.9178 - val_loss: 0.3574
# Epoch 40/40
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7588 - loss: 0.4558 - val_accuracy: 0.9178 - val_loss: 0.3455
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9178 - loss: 0.3455
# Test Accuracy: 0.9178

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train_loss', 'Valid_loss'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Valid'], loc='lower right')
plt.show()

# %% [markdown]
# # Adding Regularization to our Neural Network

# %% [markdown]
# We'll train a bigger model which will overfit, which we call Model 2. This might take a few minutes.

# %%
model_2 = Sequential([
    Dense(1000, activation='relu', input_shape=(10,)),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# using adaptative moment estimation (adam)

model_2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_2 = model_2.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# C:\Users\ed\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7907 - loss: 0.4346 - val_accuracy: 0.8493 - val_loss: 0.2924
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0
100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9307 - loss: 0.1637 - val_accuracy: 0.9178 - val_loss: 0.3617
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9429 - loss: 0.1440 - val_accuracy: 0.8630 - val_loss: 0.5831
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9353 - loss: 0.1380 - val_accuracy: 0.8219 - val_loss: 0.8264

# %%
# Evaluate the model
loss, accuracy = model_2.evaluate(X_test, Y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8904 - loss: 0.4456
# Test Accuracy: 0.8904

# %% [markdown]
# Let's do the same visualization to see what overfitting looks like in terms of the loss and accuracy.

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Loss for an overfitted model')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist_2.history['accuracy'])
plt.plot(hist_2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# To address the overfitting we see in Model 2, we'll incorporate L2 regularization and dropout in our third model here (Model 3).

# %%
from keras.layers import Dropout
from keras import regularizers

# %%
model_3 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])
# Out:
# C:\Users\ed\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
a = 0.01
b = -0.01
c = 0.1
print(a*a)
print(b*b)
print(c*c)
# Out:
# 0.0001
# 0.0001
# 0.010000000000000002

# %%
model_3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_3 = model_3.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.5799 - loss: 12.0163 - val_accuracy: 0.6712 - val_loss: 2.1162
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8242 - loss: 0.9786 - val_accuracy: 0.7534 - val_loss: 0.6796
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8417 - loss: 0.6235 - val_accuracy: 0.8356 - val_loss: 0.5386
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8546 - loss: 0.5422 - val_accuracy: 0.8219 - val_loss: 0.4753
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8653 - loss: 0.5242 - val_accuracy: 0.7945 - val_loss: 0.6008
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8531 - loss: 0.5306 - val_accuracy: 0.8904 - val_loss: 0.4847
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8729 - loss: 0.5123 - val_accuracy: 0.9315 - val_loss: 0.4448
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8691 - loss: 0.4997 - val_accuracy: 0.9041 - val_loss: 0.4552
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8661 - loss: 0.4982 - val_accuracy: 0.9041 - val_loss: 0.4553
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8676 - loss: 0.5169 - val_accuracy: 0.9315 - val_loss: 0.4291
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8721 - loss: 0.5025 - val_accuracy: 0.8904 - val_loss: 0.4420
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8661 - loss: 0.4897 - val_accuracy: 0.9178 - val_loss: 0.4295
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8600 - loss: 0.5142 - val_accuracy: 0.8767 - val_loss: 0.4883
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.
100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8638 - loss: 0.4537 - val_accuracy: 0.8767 - val_loss: 0.4475
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8668 - loss: 0.4805 - val_accuracy: 0.8767 - val_loss: 0.4463
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8874 - loss: 0.4591 - val_accuracy: 0.8767 - val_loss: 0.4394
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8805 - loss: 0.4658 - val_accuracy: 0.8904 - val_loss: 0.4092
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8645 - loss: 0.4813 - val_accuracy: 0.8493 - val_loss: 0.5317
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8676 - loss: 0.4802 - val_accuracy: 0.9041 - val_loss: 0.4123
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8638 - loss: 0.4975 - val_accuracy: 0.8904 - val_loss: 0.4402
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8744 - loss: 0.4638 - val_accuracy: 0.9178 - val_loss: 0.4108
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8623 - loss: 0.4878 - val_accuracy: 0.9178 - val_loss: 0.4262
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8836 - loss: 0.4534 - val_accuracy: 0.8904 - val_loss: 0.4079
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8721 - loss: 0.4547 - val_accuracy: 0.8767 - val_loss: 0.4578
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8744 - loss: 0.4607 - val_accuracy: 0.9041 - val_loss: 0.4279
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8767 - loss: 0.4542 - val_accuracy: 0.8493 - val_loss: 0.4391
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8592 - loss: 0.4953 - val_accuracy: 0.9041 - val_loss: 0.4285
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8798 - loss: 0.4546 - val_accuracy: 0.8904 - val_loss: 0.4345
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8790 - loss: 0.4485 - val_accuracy: 0.8904 - val_loss: 0.4452
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8820 - loss: 0.4515 - val_accuracy: 0.8767 - val_loss: 0.4417
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8714 - loss: 0.4936 - val_accuracy: 0.9178 - val_loss: 0.4212
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8790 - loss: 0.4600 - val_accuracy: 0.8767 - val_loss: 0.4446
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8592 - loss: 0.4973 - val_accuracy: 0.8904 - val_loss: 0.4997
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8851 - loss: 0.4685 - val_accuracy: 0.8904 - val_loss: 0.4867
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8851 - loss: 0.4528 - val_accuracy: 0.9041 - val_loss: 0.4307
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8767 - loss: 0.4626 - val_accuracy: 0.8904 - val_loss: 0.4041

# %%
# Evaluate the model
loss, accuracy = model_3.evaluate(X_test, Y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9315 - loss: 0.3873
# Test Accuracy: 0.9315

# %% [markdown]
# We'll now plot the loss and accuracy graphs for Model 3. You'll notice that the loss is a lot higher at the start, and that's because we've changed our loss function. To plot such that the window is zoomed in between 0 and 1.2 for the loss, we add an additional line of code (plt.ylim) when plotting

# %%
plt.plot(hist_3.history['loss'])
plt.plot(hist_3.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.2, bottom=0)
plt.show()

# %%
plt.plot(hist_3.history['accuracy'])
plt.plot(hist_3.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# As compared to Model 2, you should see that there's less overfitting!

# %%
model_3v2 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])
# Out:
# C:\Users\ed\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_3v2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_3v2 = model_3v2.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.8607 - loss: 0.4703 - val_accuracy: 0.8904 - val_loss: 0.4567
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8828 - loss: 0.4383 - val_accuracy: 0.9041 - val_loss: 0.3918
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8752 - loss: 0.4430 - val_accuracy: 0.9178 - val_loss: 0.4044
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8851 - loss: 0.4421 - val_accuracy: 0.9041 - val_loss: 0.3994
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8798 - loss: 0.4319 - val_accuracy: 0.9041 - val_loss: 0.4128
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8843 - loss: 0.4344 - val_accuracy: 0.9315 - val_loss: 0.4055
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8721 - loss: 0.4406 - val_accuracy: 0.9178 - val_loss: 0.4129
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8798 - loss: 0.4316 - val_accuracy: 0.9315 - val_loss: 0.4033
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8889 - loss: 0.4389 - val_accuracy: 0.8904 - val_loss: 0.4320
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8820 - loss: 0.4348 - val_accuracy: 0.9178 - val_loss: 0.4043
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8752 - loss: 0.4511 - val_accuracy: 0.9041 - val_loss: 0.4196
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8904 - loss: 0.4258 - val_accuracy: 0.9178 - val_loss: 0.4002
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8638 - loss: 0.4675 - val_accuracy: 0.8630 - val_loss: 0.4023
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8790 - loss: 0.4563 - val_accuracy: 0.8904 - val_loss: 0.4797
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8729 - loss: 0.4462 - val_accuracy: 0.9178 - val_loss: 0.4110
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8851 - loss: 0.4299 - val_accuracy: 0.8767 - val_loss: 0.3937
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8805 - loss: 0.4394 - val_accuracy: 0.8767 - val_loss: 0.4418
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8843 - loss: 0.4361 - val_accuracy: 0.9178 - val_loss: 0.3977
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8790 - loss: 0.4455 - val_accuracy: 0.9041 - val_loss: 0.4096
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8866 - loss: 0.4249 - val_accuracy: 0.8904 - val_loss: 0.3916
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8683 - loss: 0.4578 - val_accuracy: 0.9178 - val_loss: 0.4032
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8858 - loss: 0.4351 - val_accuracy: 0.9178 - val_loss: 0.4018
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8828 - loss: 0.4355 - val_accuracy: 0.8767 - val_loss: 0.4334
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8836 - loss: 0.4432 - val_accuracy: 0.9178 - val_loss: 0.3997
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.
100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8836 - loss: 0.4338 - val_accuracy: 0.9315 - val_loss: 0.4037
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8858 - loss: 0.4256 - val_accuracy: 0.8904 - val_loss: 0.4700
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8729 - loss: 0.4446 - val_accuracy: 0.8904 - val_loss: 0.3988
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8820 - loss: 0.4345 - val_accuracy: 0.8904 - val_loss: 0.3966
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8881 - loss: 0.4273 - val_accuracy: 0.8904 - val_loss: 0.4321
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8714 - loss: 0.4385 - val_accuracy: 0.9315 - val_loss: 0.4008
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8858 - loss: 0.4300 - val_accuracy: 0.8904 - val_loss: 0.4397
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8843 - loss: 0.4382 - val_accuracy: 0.8904 - val_loss: 0.4166
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8737 - loss: 0.4495 - val_accuracy: 0.8904 - val_loss: 0.4302
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8775 - loss: 0.4375 - val_accuracy: 0.9178 - val_loss: 0.4083
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8896 - loss: 0.4276 - val_accuracy: 0.8767 - val_loss: 0.4428
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8851 - loss: 0.4364 - val_accuracy: 0.8767 - val_loss: 0.4523
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8866 - loss: 0.4281 - val_accuracy: 0.8767 - val_loss: 0.4539
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8866 - loss: 0.4363 - val_accuracy: 0.9041 - val_loss: 0.4159
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8798 - loss: 0.4316 - val_accuracy: 0.8767 - val_loss: 0.3917

# %%
plt.plot(hist_3v2.history['loss'])
plt.plot(hist_3v2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.2, bottom=0)
plt.show()

# %%
plt.plot(hist_3v2.history['accuracy'])
plt.plot(hist_3v2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# What do you think? you decide which DP and L2 are better !

# %% [markdown]
# # Regression (Finding a value)

# %% [markdown]
# Which features are available in the dataset?
#
# Which features are categorical?
#
# Which features are numerical?
#
# Which features contain blank, null or empty values?
#
# What are the data types for various features?
#
# What is the distribution of numerical feature values across the samples?
#
# Which features are more correlated to the price?

# %% [markdown]
# Dataset
# This dataset contains house sale prices for King County, which includes Seattle.
# It includes homes sold between May 2014 and May 2015.
# 21 columns. (features)
# 21597 rows.
# Feature Columns
#
# id: Unique ID for each home sold
#
# date: Date of the home sale
#
# price: Price of each home sold
#
# bedrooms: Number of bedrooms
#
# bathrooms: Number of bathrooms, where .5 accounts for a room with a toilet but no shower
#
# sqft_living: Square footage of the apartments interior living space
#
# sqft_lot: Square footage of the land space
#
# floors: Number of floors
#
# waterfront: - A dummy variable for whether the apartment was overlooking the waterfront or not
#
# view: An index from 0 to 4 of how good the view of the property was
#
# condition: - An index from 1 to 5 on the condition of the apartment,
#
# grade: An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
#
# sqft_above: The square footage of the interior housing space that is above ground level
#
# sqft_basement: The square footage of the interior housing space that is below ground level
#
# yr_built: The year the house was initially built
#
# yr_renovated: The year of the house’s last renovation
#
# zipcode: What zipcode area the house is in
#
# lat: Lattitude
#
# long: Longitude
#
# sqft_living15: The square footage of interior housing living space for the nearest 15 neighbors
#
# sqft_lot15: The square footage of the land lots of the nearest 15 neighbors

# %%
# data analysis
import pandas as pd
import numpy as np

# models
from keras import layers
from keras import preprocessing
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam   # if keras does not find it

# preprocessing
from sklearn import preprocessing

# Split
from sklearn.model_selection import train_test_split

# %%
housePrices=pd.read_excel(r'./kc_house_data_yr.xlsx')
print(len(housePrices))

# preview the data desde la cabeza
housePrices.head()
# Out:
# 21613
#            id      date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013  221900         3       1.00         1180      5650
# 1  6414100192  20141209  538000         3       2.25         2570      7242
# 2  5631500400  20150225  180000         2       1.00          770     10000
# 3  2487200875  20141209  604000         4       3.00         1960      5000
# 4  1954400510  20150218  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
housePrices.tail()  # previewing the data from the backwards, this is from the tail !
# Out:
#                id      date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521  360000         3       2.50         1530
# 21609  6600060120  20150223  400000         4       2.50         2310
# 21610  1523300141  20140623  402101         2       0.75         1020
# 21611   291310100  20150116  400000         3       2.50         1600
# 21612  1523300157  20141015  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 21608           1530        1509
# 21609           1830        7200
# 21610           1020        2007
# 21611           1410        1287
# 21612           1020        1357
#
# [5 rows x 21 columns]

# %%
housePrices.shape
# Out:
# (21613, 21)

# %%
len(housePrices.columns)
# Out:
# 21

# %%
housePrices.dtypes   # Investigation data types is always good !  object type are strings**
# Out:
# id                 int64
# date               int64
# price              int64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
housePrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  int64
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(17)
# memory usage: 3.5 MB

# %% [markdown]
# Which features contain blank, null or empty values?
#
# We can check for missing values with pandas isnull(). This indicates whether values are missing or not. Then we can sum all the values to check every column.

# %%
# Number of null values per feature
housePrices.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# What is the distribution of numerical feature values across the samples?

# %%
housePrices.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# date           21613.0  2.014390e+07  4.436582e+03  2.014050e+07
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# date           2.014072e+07  2.014102e+07  2.015022e+07  2.015053e+07
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# __Completing__
#
# Since there are no missing values we do not need to complete any values.

# %% [markdown]
# __Preparation__
#
# Id feature may be dropped from our analysis since it does not add value. Date feature may be dropped since we are going to do feature engineering and make a year and month column. Zipcode feature is a special case, we could use it, but since we do not know exactly the zones of King County we are just going to drop it. Treat strings as categories. Although Zip code is numeric, we cannot treat it as a number in the model, it may be converted to a string.

# %% [markdown]
# __Creating__
#
# We may want to create a new feature called Year based on Date to analyze the price change throughout the years. We may want to create a new feature called Month based on Date to analyze the price change throughout the months.

# %% [markdown]
# __Correlation__
#
# We want to know how well does each feature correlate with Price. We want to do this early in our project and match these quick correlations with modelled correlations later in the project.
#
# Analyze by visualizing data using the __Pearson correlation matrix__
#
# It plots a coefficient to examine the strength and direction of the linear relationship between two continuous variables.
#
# The correlation coefficient can range in value from −1 to +1. The larger the absolute value of the coefficient, the stronger the relationship between the variables. For the Pearson correlation, an absolute value of 1 indicates a perfect linear relationship. A correlation close to 0 indicates no linear relationship between the variables.
#
# The sign of the coefficient indicates the direction of the relationship. If both variables tend to increase or decrease together, the coefficient is positive, and the line that represents the correlation slopes upward. If one variable tends to increase as the other decreases, the coefficient is negative, and the line that represents the correlation slopes downward.

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\ed\documents\maestria\jupyter\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ed\documents\maestria\jupyter\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style='whitegrid', font_scale=1)

plt.figure(figsize=(13,13))
plt.title('Pearson Correlation Matrix',fontsize=25)
sns.heatmap(housePrices.corr(),linewidths=0.25,vmax=0.7,square=True,cmap='GnBu',linecolor='w',
            annot=True, annot_kws={'size':7}, cbar_kws={'shrink': .7})
# Out:
# <Axes: title={'center': 'Pearson Correlation Matrix'}>

# %% [markdown]
# Which features are more correlated to the price?
#
# This allow us to explore labels that are highly correlated to the price.
# sqft_living looks like a highly correlated label to the price, as well as grade, sqft_above, sqft_living15 and bathrooms.

# %%
price_corr = housePrices.corr()['price'].sort_values(ascending=False)
print(price_corr)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# date             0.003033
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %% [markdown]
# __Price feature__
#
# Most of the house prices are between 0 and 1,500,000.
#
# The average house price is $540,000.
#
# Keep in mind that it may be a good idea to drop extreme values. For instance, we could focus on house from 0 to $3,000,000 and
# drop the other ones.
#
# It seems that there is a positive linear relationship between the price and sqft_living.
#
# An increase in living space generally corresponds to an increase in house price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.histplot(housePrices['price'], ax=axes[0])
sns.scatterplot(x='price',y='sqft_living', data=housePrices, ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Price in millions (USD)', ylabel='Frequency', title='Price Distribuition')
axes[1].set(xlabel='Price', ylabel='Sqft Living', title='Price vs Sqft Living')
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()

# %% [markdown]
# __Bedrooms and floors box plots__
#
# Box plot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot. Outliers may be plotted as individual points. The spacings between the different parts of the box indicate the degree of dispersion (spread).
#
# We can see outliers plotted as individual points; this probably are the more expensive houses.
# We can see that the price tends to go up when the house has more bedrooms.

# %%
sns.set(style="whitegrid", font_scale=1)

f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=housePrices['bedrooms'],y=housePrices['price'], ax=axes[0])
sns.boxplot(x=housePrices['floors'],y=housePrices['price'], ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Bedrooms', ylabel='Price', title='Bedrooms vs Price Box Plot')
axes[1].set(xlabel='Floors', ylabel='Price', title='Floors vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Floors'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Floors vs Price Box Plot')]

# %% [markdown]
# __Waterfront, view and grade box plots__
#
# Waterfront houses tends to have a better price value.
# The price of waterfront houses tends to be more disperse and the price of houses without waterfront tend to be more concentrated.
# Grade and waterfront effect price. View seem to effect less but it also has an effect on price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=housePrices['waterfront'],y=housePrices['price'], ax=axes[0])
sns.boxplot(x=housePrices['view'],y=housePrices['price'], ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Waterfront', ylabel='Price', title='Waterfront vs Price Box Plot')
axes[1].set(xlabel='View', ylabel='Price', title='View vs Price Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
sns.boxplot(x=housePrices['grade'],y=housePrices['price'], ax=axe)
sns.despine(left=True, bottom=True)
axe.set(xlabel='Grade', ylabel='Price', title='Grade vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Grade'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Grade vs Price Box Plot')]

# %%
[housePrices['view'].unique().tolist() for view in housePrices.columns]
# Out:
# [[0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1]]

# %% [markdown]
# __Working with Feature Data = Feature engineering__
#
# __Correcting by dropping features__
#
# By dropping features, we are dealing with fewer data points. Speeds up our notebook and eases the analysis. Based on our assumptions and decisions we want to drop the Id, zipcode and Date features.

# %%
housePrices = housePrices.drop('id',axis=1)
housePrices = housePrices.drop('zipcode',axis=1)
print(housePrices.columns.values)
# Out:
# ['date' 'price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot' 'floors'
#  'waterfront' 'view' 'condition' 'grade' 'sqft_above' 'sqft_basement'
#  'yr_built' 'yr_renovated' 'lat' 'long' 'sqft_living15' 'sqft_lot15']

# %% [markdown]
# We want to engineer the date feature to make a year and month column. The feature date is as a string. With pd.to_datetime we can convert an argument to datetime.

# %%
housePrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  int64
#  1   price          21613 non-null  int64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
#  17  sqft_living15  21613 non-null  int64
#  18  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(15)
# memory usage: 3.1 MB

# %%
housePrices['date'] = housePrices['date'].values.astype(str)

# %%
housePrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  object
#  1   price          21613 non-null  int64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
#  17  sqft_living15  21613 non-null  int64
#  18  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(14), object(1)
# memory usage: 3.1+ MB

# %%
housePrices['date'] = pd.to_datetime(housePrices['date'])

housePrices['month'] = housePrices['date'].apply(lambda date:date.month)
housePrices['year'] = housePrices['date'].apply(lambda date:date.year)

housePrices = housePrices.drop('date',axis=1)

# Check the new columns
print(housePrices.columns.values)
# Out:
# ['price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot' 'floors'
#  'waterfront' 'view' 'condition' 'grade' 'sqft_above' 'sqft_basement'
#  'yr_built' 'yr_renovated' 'lat' 'long' 'sqft_living15' 'sqft_lot15'
#  'month' 'year']

# %%
print('now the dataframe looks like this:')
housePrices.head(5)
# Out:
# now the dataframe looks like this:
#     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900         3       1.00         1180      5650     1.0           0
# 1  538000         3       2.25         2570      7242     2.0           0
# 2  180000         2       1.00          770     10000     1.0           0
# 3  604000         4       3.00         1960      5000     1.0           0
# 4  510000         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  month  year
# 0  47.5112 -122.257           1340        5650     10  2014
# 1  47.7210 -122.319           1690        7639     12  2014
# 2  47.7379 -122.233           2720        8062      2  2015
# 3  47.5208 -122.393           1360        5000     12  2014
# 4  47.6168 -122.045           1800        7503      2  2015

# %% [markdown]
# __House price trends, Price vs month, vs year__
#
# Looking the box plots we notice that there is not a big difference between 2014 and 2015.
# The number of houses sold by month tends to be similar every month.
# The line plot show that around April there is an increase in house prices.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x='year',y='price',data=housePrices, ax=axes[0])
sns.boxplot(x='month',y='price',data=housePrices, ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Year', ylabel='Price', title='Price by Year Box Plot')
axes[1].set(xlabel='Month', ylabel='Price', title='Price by Month Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
housePrices.groupby('month').mean()['price'].plot()
sns.despine(left=True, bottom=True)
axe.set(xlabel='Month', ylabel='Price', title='Price Trends')
# Out:
# [Text(0.5, 0, 'Month'), Text(0, 0.5, 'Price'), Text(0.5, 1.0, 'Price Trends')]

# %% [markdown]
# __Splitting data into training, validation and testing sets__
#
# Instead of a class, Regression problems are measured by a `mean squared error or "MSE"`

# %% [markdown]
# Again, in supervised learning, we are training our model with a given dataset of examples f(X) = y, where X are a set of variables, y is the value to predict and f is the DNN !

# %%
# Features
X = housePrices.drop('price',axis=1)

# Label
y = housePrices['price']

# Split
X_train, X_valid, y_train, y_valid = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
print(X_train.shape)
print(X_valid.shape)
print(y_train.shape)
print(y_valid.shape)
# Out:
# (15129, 19)
# (6484, 19)
# (15129,)
# (6484,)

# %% [markdown]
# __Scaling Data__
#
# In Machine Learning, including Deep Learning, Gaussian distributions are the key, so adjusting data to gaussian is kean
# Even more, having a standard deviation of 1 and median of 0 is ideal.
#
# fit_transform(X[, y]): Fit to data, then transform it.
# transform(X): Scale features of X according to feature_range.

# %%
# scaling and train test split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler()

# fit and transfrom
X_train = scaler.fit_transform(X_train)

# transform for avoiding data leakage
X_valid = scaler.transform(X_valid)

# everything has been scaled between 1 and 0
print('Max: ',X_train.max())
print('Min: ', X_train.min())
# Out:
# Max:  1.0000000000000002
# Min:  0.0

# %% [markdown]
# __Creating a model == The f, the DNN__
#
# We estimate the number of neurons (units) from our features. Ex: X_train.shape (15129, 19). The optimizer is asking how you want to perform this gradient descent. In this case we are using the Adam optimizer and the mean square error loss function.

# %%
model = Sequential()

# input layer
model.add(Dense(19,activation='relu'))

# hidden layers
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

# output layer
model.add(Dense(1))  # This is the decision layer class or value depending on the need !

model.compile(optimizer='adam',loss='mse') #mean square error

# %% [markdown]
# __Training the model, the f, the DNN__
#
# Now that the model, architecture, 'stomach' is ready, we can fit the model into the data.
#
# Since the dataset is large, we are going to use batch_size. It is typical to use batches of the power of 2 (32, 64, 128, 256...). In this case we are using 128. The smaller the batch size, the longer is going to take.

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_valid,y_valid.values),
          batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 423630471168.0000 - val_loss: 433037017088.0000
# Epoch 2/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 422979305472.0000 - val_loss: 430670118912.0000
# Epoch 3/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 412939845632.0000 - val_loss: 406413017088.0000
# Epoch 4/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 358075498496.0000 - val_loss: 310364962816.0000
# Epoch 5/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 226174533632.0000 - val_loss: 158507253760.0000
# Epoch 6/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 116021542912.0000 - val_loss: 105507536896.0000
# Epoch 7/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 98688073728.0000 - val_loss: 103144226816.0000
# Epoch 8/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 97301798912.0000 - val_loss: 101676859392.0000
# Epoch 9/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 95995043840.0000 - val_loss: 100320559104.0000
# Epoch 10/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 94704304128.0000 - val_loss: 98885304320.0000
# Epoch 11/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 93360218112.0000 - val_loss: 97416962048.0000
# Epoch 12/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 91967700992.0000 - val_loss: 95858606080.0000
# Epoch 13/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 90523516928.0000 - val_loss: 94268104704.0000
# Epoch 14/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 88995004416.0000 - val_loss: 92606103552.0000
# Epoch 15/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 87414669312.0000 - val_loss: 90850738176.0000
# Epoch 16/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 85771444224.0000 - val_loss: 89034514432.0000
# Epoch 17/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 84062617600.0000 - val_loss: 87062421504.0000
# Epoch 18/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 82249023488.0000 - val_loss: 85122809856.0000
# Epoch 19/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 80332554240.0000 - val_loss: 82992168960.0000
# Epoch 20/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 78343479296.0000 - val_loss: 80780640256.0000
# Epoch 21/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 76293505024.0000 - val_loss: 78480089088.0000
# Epoch 22/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 74171580416.0000 - val_loss: 76142952448.0000
# Epoch 23/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 71967211520.0000 - val_loss: 73747914752.0000
# Epoch 24/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69769609216.0000 - val_loss: 71250370560.0000
# Epoch 25/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67477184512.0000 - val_loss: 68787380224.0000
# Epoch 26/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65322463232.0000 - val_loss: 66411782144.0000
# Epoch 27/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63204548608.0000 - val_loss: 64135815168.0000
# Epoch 28/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 61229174784.0000 - val_loss: 62042345472.0000
# Epoch 29/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 59476832256.0000 - val_loss: 60225982464.0000
# Epoch 30/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 57880154112.0000 - val_loss: 58423877632.0000
# Epoch 31/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 56499437568.0000 - val_loss: 57101660160.0000
# Epoch 32/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 55330516992.0000 - val_loss: 55688851456.0000
# Epoch 33/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 54283632640.0000 - val_loss: 54571065344.0000
# Epoch 34/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53370142720.0000 - val_loss: 53588926464.0000
# Epoch 35/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52550791168.0000 - val_loss: 52870422528.0000
# Epoch 36/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51809947648.0000 - val_loss: 52009250816.0000
# Epoch 37/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51186503680.0000 - val_loss: 51392086016.0000
# Epoch 38/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50577211392.0000 - val_loss: 50699251712.0000
# Epoch 39/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50027753472.0000 - val_loss: 50164154368.0000
# Epoch 40/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49496539136.0000 - val_loss: 49598296064.0000
# Epoch 41/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48985587712.0000 - val_loss: 49251057664.0000
# Epoch 42/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48559312896.0000 - val_loss: 48646852608.0000
# Epoch 43/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48124006400.0000 - val_loss: 48182468608.0000
# Epoch 44/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47684616192.0000 - val_loss: 47756447744.0000
# Epoch 45/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47280848896.0000 - val_loss: 47376773120.0000
# Epoch 46/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46878834688.0000 - val_loss: 46946676736.0000
# Epoch 47/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46482472960.0000 - val_loss: 46566969344.0000
# Epoch 48/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46101549056.0000 - val_loss: 46129721344.0000
# Epoch 49/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45703176192.0000 - val_loss: 45774786560.0000
# Epoch 50/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45344698368.0000 - val_loss: 45391839232.0000
# Epoch 51/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45062582272.0000 - val_loss: 45101600768.0000
# Epoch 52/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44738224128.0000 - val_loss: 44722974720.0000
# Epoch 53/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44430749696.0000 - val_loss: 44451667968.0000
# Epoch 54/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44170035200.0000 - val_loss: 44292890624.0000
# Epoch 55/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43878862848.0000 - val_loss: 43862339584.0000
# Epoch 56/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43612274688.0000 - val_loss: 43598123008.0000
# Epoch 57/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 43329650688.0000 - val_loss: 43410767872.0000
# Epoch 58/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43067097088.0000 - val_loss: 43064381440.0000
# Epoch 59/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42849820672.0000 - val_loss: 42808340480.0000
# Epoch 60/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42579206144.0000 - val_loss: 42511056896.0000
# Epoch 61/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42301509632.0000 - val_loss: 42291523584.0000
# Epoch 62/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42074312704.0000 - val_loss: 41978789888.0000
# Epoch 63/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41758113792.0000 - val_loss: 41696010240.0000
# Epoch 64/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41540677632.0000 - val_loss: 41422635008.0000
# Epoch 65/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 41278910464.0000 - val_loss: 41175674880.0000
# Epoch 66/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41009987584.0000 - val_loss: 40911687680.0000
# Epoch 67/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 
400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31715336192.0000 - val_loss: 31079712768.0000
# Epoch 212/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31692079104.0000 - val_loss: 31122225152.0000
# Epoch 213/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31691665408.0000 - val_loss: 31066855424.0000
# Epoch 214/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31679875072.0000 - val_loss: 31039336448.0000
# Epoch 215/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31613396992.0000 - val_loss: 31044497408.0000
# Epoch 216/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31641217024.0000 - val_loss: 31036090368.0000
# Epoch 217/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31586021376.0000 - val_loss: 30976872448.0000
# Epoch 218/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31574806528.0000 - val_loss: 31143342080.0000
# Epoch 219/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31613202432.0000 - val_loss: 30942115840.0000
# Epoch 220/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31536693248.0000 - val_loss: 30957086720.0000
# Epoch 221/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31537590272.0000 - val_loss: 30971185152.0000
# Epoch 222/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31534348288.0000 - val_loss: 30897289216.0000
# Epoch 223/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31509317632.0000 - val_loss: 30866020352.0000
# Epoch 224/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31502917632.0000 - val_loss: 30935867392.0000
# Epoch 225/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31455414272.0000 - val_loss: 30899554304.0000
# Epoch 226/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31497525248.0000 - val_loss: 31024783360.0000
# Epoch 227/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31483430912.0000 - val_loss: 30821521408.0000
# Epoch 228/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31413526528.0000 - val_loss: 30797488128.0000
# Epoch 229/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31386005504.0000 - val_loss: 30819702784.0000
# Epoch 230/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31401515008.0000 - val_loss: 30774951936.0000
# Epoch 231/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31367933952.0000 - val_loss: 30745516032.0000
# Epoch 232/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31334963200.0000 - val_loss: 30733410304.0000
# Epoch 233/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31313881088.0000 - val_loss: 30709870592.0000
# Epoch 234/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31309455360.0000 - val_loss: 30722865152.0000
# Epoch 235/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31302205440.0000 - val_loss: 30684182528.0000
# Epoch 236/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31275540480.0000 - val_loss: 30658056192.0000
# Epoch 237/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31248472064.0000 - val_loss: 30685249536.0000
# Epoch 238/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31233624064.0000 - val_loss: 30627565568.0000
# Epoch 239/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31220670464.0000 - val_loss: 30677098496.0000
# Epoch 240/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31201118208.0000 - val_loss: 30615050240.0000
# Epoch 241/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31197181952.0000 - val_loss: 30578853888.0000
# Epoch 242/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31182190592.0000 - val_loss: 30590021632.0000
# Epoch 243/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31167760384.0000 - val_loss: 30556135424.0000
# Epoch 244/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31119456256.0000 - val_loss: 30540544000.0000
# Epoch 245/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31106908160.0000 - val_loss: 30508167168.0000
# Epoch 246/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31094343680.0000 - val_loss: 30516795392.0000
# Epoch 247/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31109718016.0000 - val_loss: 30498406400.0000
# Epoch 248/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31054960640.0000 - val_loss: 30459822080.0000
# Epoch 249/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 31084238848.0000 - val_loss: 30444216320.0000
# Epoch 250/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31056185344.0000 - val_loss: 30508877824.0000
# Epoch 251/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31001663488.0000 - val_loss: 30436048896.0000
# Epoch 252/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31017795584.0000 - val_loss: 30408122368.0000
# Epoch 253/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30984501248.0000 - val_loss: 30444873728.0000
# Epoch 254/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30973577216.0000 - val_loss: 30399713280.0000
# Epoch 255/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30976735232.0000 - val_loss: 30354622464.0000
# Epoch 256/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30960867328.0000 - val_loss: 30339903488.0000
# Epoch 257/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30912020480.0000 - val_loss: 30370004992.0000
# Epoch 258/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30911057920.0000 - val_loss: 30309005312.0000
# Epoch 259/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 
400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29362853888.0000 - val_loss: 28984068096.0000
# Epoch 356/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29362362368.0000 - val_loss: 28965359616.0000
# Epoch 357/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29348315136.0000 - val_loss: 28956002304.0000
# Epoch 358/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29349816320.0000 - val_loss: 28935458816.0000
# Epoch 359/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29286039552.0000 - val_loss: 28934746112.0000
# Epoch 360/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29262325760.0000 - val_loss: 28939765760.0000
# Epoch 361/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29270517760.0000 - val_loss: 29114415104.0000
# Epoch 362/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 29252521984.0000 - val_loss: 28932837376.0000
# Epoch 363/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29250435072.0000 - val_loss: 28866783232.0000
# Epoch 364/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29225283584.0000 - val_loss: 28857462784.0000
# Epoch 365/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29219659776.0000 - val_loss: 28853286912.0000
# Epoch 366/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29288374272.0000 - val_loss: 28847194112.0000
# Epoch 367/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29143451648.0000 - val_loss: 28902899712.0000
# Epoch 368/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29161172992.0000 - val_loss: 28819005440.0000
# Epoch 369/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29143875584.0000 - val_loss: 28805206016.0000
# Epoch 370/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29115654144.0000 - val_loss: 28787492864.0000
# Epoch 371/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29091473408.0000 - val_loss: 28762572800.0000
# Epoch 372/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29082357760.0000 - val_loss: 28749578240.0000
# Epoch 373/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29054918656.0000 - val_loss: 28798861312.0000
# Epoch 374/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29060812800.0000 - val_loss: 28755580928.0000
# Epoch 375/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29057454080.0000 - val_loss: 28831244288.0000
# Epoch 376/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29040021504.0000 - val_loss: 28716771328.0000
# Epoch 377/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29025771520.0000 - val_loss: 28724596736.0000
# Epoch 378/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28971657216.0000 - val_loss: 28703076352.0000
# Epoch 379/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28991141888.0000 - val_loss: 28684541952.0000
# Epoch 380/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28933251072.0000 - val_loss: 28682100736.0000
# Epoch 381/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28945152000.0000 - val_loss: 28639305728.0000
# Epoch 382/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28911083520.0000 - val_loss: 28641988608.0000
# Epoch 383/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28895412224.0000 - val_loss: 28636907520.0000
# Epoch 384/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28869320704.0000 - val_loss: 28608731136.0000
# Epoch 385/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28894511104.0000 - val_loss: 28602075136.0000
# Epoch 386/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28843384832.0000 - val_loss: 28585199616.0000
# Epoch 387/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28880160768.0000 - val_loss: 28581056512.0000
# Epoch 388/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28819300352.0000 - val_loss: 28565772288.0000
# Epoch 389/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28824899584.0000 - val_loss: 28566204416.0000
# Epoch 390/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28777809920.0000 - val_loss: 28544137216.0000
# Epoch 391/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28769781760.0000 - val_loss: 28599998464.0000
# Epoch 392/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28756273152.0000 - val_loss: 28543731712.0000
# Epoch 393/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28743450624.0000 - val_loss: 28523876352.0000
# Epoch 394/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28719527936.0000 - val_loss: 28500989952.0000
# Epoch 395/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28688347136.0000 - val_loss: 28489914368.0000
# Epoch 396/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28688539648.0000 - val_loss: 28480178176.0000
# Epoch 397/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28727263232.0000 - val_loss: 28548100096.0000
# Epoch 398/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28659638272.0000 - val_loss: 28472772608.0000
# Epoch 399/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28663611392.0000 - val_loss: 28507643904.0000
# Epoch 400/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28616075264.0000 - val_loss: 28501053440.0000

# %% [markdown]
# __Training loss per epoch__
#
# This plot shows the training loss per epoch.
# This plot helps us to see if there is overfitting in the model. In this case there is no overfitting because both lines go down at the same time.

# %%
losses = pd.DataFrame(model.history.history)

plt.figure(figsize=(15,5))
sns.lineplot(data=losses,lw=3)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss per Epoch')
sns.despine()

# %% [markdown]
# __Regression Evaluation Metrics__
#
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
#
# n∑i=1/n|yi−y^i|
#
# Mean Squared Error (MSE) is the mean of the squared errors:
#
# n∑i=1/n(yi−y^i)2
#
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
#
# n∑i=1 √1/n(yi−y^i)2
#
#
# __Comparing these metrics__
#
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.

# %% [markdown]
# __Prediction (What we do on brand new data)__
#
# In this part we are giving the model the test set to get a list of predictions. Then we compare the correct values with the list of predictions. We use different metrics to compare the predictions, in this case we use MAE, MSE, RMSE and Variance Regression Score.
#
# Let us start by analyzing the MAE, which is 103,500. This means that our model is off on average about `$100,000`.
#
# Is that MAE good or bad?
#
# For that we must take into account our original data set and see what kind of values we have. For instance, the mean is 540,000, therefore the MEA is about 19% of the mean price. This is not a particularly good result.
#
# To better understand this error, we can use the variance regression score, where the best possible score is 1.0 and lower values are worse. This tells you how much variance is being explain by your model. In our case we have 0.80 which is a normal result.

# %%
# evaluation on test data
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score
from sklearn.metrics import classification_report,confusion_matrix

# %%
# predictions on the test set
predictions = model.predict(X_valid)

print('MAE: ', mean_absolute_error(y_valid,predictions))
print('MSE: ', mean_squared_error(y_valid,predictions))
print('RMSE: ', np.sqrt(mean_squared_error(y_valid,predictions)))
print('Variance Regression Score: ', explained_variance_score(y_valid,predictions))

print('\n\nDescriptive Statistics:\n',housePrices['price'].describe())
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MAE:  104618.2421875
# MSE:  28501051392.0
# RMSE:  168822.5440869791
# Variance Regression Score:  0.7969118261378875
#
#
# Descriptive Statistics:
#  count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# __Model predictions vs perfect fit__
#
# We can compare the model predictions with a perfect fit to see how accurate the model is.
#
# The red line represents the perfect prediction.
#
# We are being punish by the outliers, which are the expensive houses. Our model is not good predicting luxury houses.
#
# On the other hand, our model is good predicting the price of houses between 0 and $2 million. There is clearly a good fit.
#
# It may be worth it retraining our model just on price houses below $3 million.  df[df['price'] <= 3000000]

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))

# Our model predictions
plt.scatter(y_valid,predictions)

# Perfect predictions
plt.plot(y_valid,y_valid,'r')

errors = y_valid.values.reshape(6484, 1) - predictions
sns.histplot(errors, ax=axes[0])

sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Error', ylabel='', title='Error Histogram')
axes[1].set(xlabel='Test True Y', ylabel='Model Predictions', title='Model Predictions vs Perfect Fit')
# Out:
# [Text(0.5, 0, 'Test True Y'),
#  Text(0, 0.5, 'Model Predictions'),
#  Text(0.5, 1.0, 'Model Predictions vs Perfect Fit')]

# %% [markdown]
# __Predicting a new comer house__
#
# We are going to use the model to predict the price on a brand-new house. We are going to choose the first house of the data set and drop the price. single_house is going to have all the features that we need to predict the price. After that we need to reshape the variable and scale the features.
#
# The original price is 221,900 and the model prediction is ~ $285,000.

# %%
# features of new house
single_house = housePrices.drop('price',axis=1).iloc[0]
print(f'Features of new house:\n {single_house}')

# reshape the numpy array and scale the features
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# run the model and get the price prediction
print('\nPrediction Price:', model.predict(single_house)[0,0])

# original price
print('\nOriginal Price:', housePrices.iloc[0]['price'])
# Out:
# Features of new house:
#  bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# month              10.0000
# year             2014.0000
# Name: 0, dtype: float64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Prediction Price: 285265.62
#
# Original Price: 221900.0
# C:\Users\ed\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Go ahead and create a model for houses with a less skewed distribution

# %%
housePrices2 = housePrices[housePrices['price'] <= 3000000]
housePrices2.head(10)
# Out:
#      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   221900         3       1.00         1180      5650     1.0           0
# 1   538000         3       2.25         2570      7242     2.0           0
# 2   180000         2       1.00          770     10000     1.0           0
# 3   604000         4       3.00         1960      5000     1.0           0
# 4   510000         3       2.00         1680      8080     1.0           0
# 5  1225000         4       4.50         5420    101930     1.0           0
# 6   257500         3       2.25         1715      6819     2.0           0
# 7   291850         3       1.50         1060      9711     1.0           0
# 8   229500         3       1.00         1780      7470     1.0           0
# 9   323000         3       2.50         1890      6560     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
# 5     0          3     11        3890           1530      2001             0
# 6     0          3      7        1715              0      1995             0
# 7     0          3      7        1060              0      1963             0
# 8     0          3      7        1050            730      1960             0
# 9     0          3      7        1890              0      2003             0
#
#        lat     long  sqft_living15  sqft_lot15  month  year
# 0  47.5112 -122.257           1340        5650     10  2014
# 1  47.7210 -122.319           1690        7639     12  2014
# 2  47.7379 -122.233           2720        8062      2  2015
# 3  47.5208 -122.393           1360        5000     12  2014
# 4  47.6168 -122.045           1800        7503      2  2015
# 5  47.6561 -122.005           4760      101930      5  2014
# 6  47.3097 -122.327           2238        6819      6  2014
# 7  47.4095 -122.315           1650        9711      1  2015
# 8  47.5123 -122.337           1780        8113      4  2015
# 9  47.3684 -122.031           2390        7570      3  2015

# %% [markdown]
# Exercise
